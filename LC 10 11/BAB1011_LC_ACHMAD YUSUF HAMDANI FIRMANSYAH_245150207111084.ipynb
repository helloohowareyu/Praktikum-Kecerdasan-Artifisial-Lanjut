# %% [markdown]
# <a href="https://colab.research.google.com/github/helloohowareyu/Praktikum-Kecerdasan-Artifisial-Lanjut/blob/main/BAB1011_LC_ACHMAD%20YUSUF%20HAMDANI%20FIRMANSYAH_245150207111084_(3).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Live Coding BAB 10 dan 11 Hierarchical Clustering dan Metode Evaluasi Clustering**

# %% [markdown]
# - Nama    :
# - NIM     :
# - Kelas   :

# %% [markdown]
# ## **Import Library**

# %%
import os

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.decomposition import PCA
from sklearn.metrics import silhouette_score, calinski_harabasz_score, davies_bouldin_score, adjusted_rand_score

from scipy.spatial.distance import pdist, squareform
from scipy.cluster.hierarchy import dendrogram, linkage, fcluster

# %% [markdown]
# ## **1. Data Preparation**

# %% [markdown]
# ### **1.1. Upload Data**

# %%
df = pd.read_csv('___')

# %% [markdown]
# ### **1.2. Data Overview**

# %% [markdown]
# 1. Tampilkan informasi statistik deskriptif dari data tersebut
# 2. Tampilkan informasi statistik deskriptif dari masing-masing tipe `wine`, bandingkan wine tipe `red` and `white`.
# 4. Ada berapa level kualitas `wine` dan level apa saja?
# 3. Tampilkan informasi statistik deskriptif dari masing-masing kualitas `wine`.
# 3. Cari tahu fitur apa yang memiliki korelasi tertinggi terhadap kualitas `wine`.

# %% [markdown]
# ## **2. Data Preprocessing**

# %% [markdown]
# Lakukan Preprocessing data, seperti handle Missing Value, handling Duplicated data, Standarisasi, Label Encoding pada fitur kategorikal, serta drop kolom 'quality'.

# %% [markdown]
# ### Transformasi data dengan PCA
#
# transform dimensi dataset menjadi 2 fitur

# %%
pca = PCA(n_components=___)
pca_result = pca.fit_transform(df[____])

# Add PCA results to the dataframe
df['____'] = pca_result[:, 0]
df['____'] = pca_result[:, 1]

# %% [markdown]
# ### Lakukan Sampling dataset dengan menyisakan 1000 data

# %% [markdown]
# ## **3. Hierarchical Clustering**

# %% [markdown]
# ### **A. Hitung jarak dan buat matriks jarak dengan metode Euclidean dan Manhattan**

# %% [markdown]
# ### **B. Single Linkage**

# %% [markdown]
# ### **C. Complete Linkage**

# %% [markdown]
# ### **D. Average Linkage**

# %% [markdown]
# ### **D. Buat Cluster**

# %% [markdown]
# Buat Cluster dengan fcluster dengan parameter criteion='distance' dan t bebas sesuai eksperimen kalian

# %%
clusters_single =
clusters_complete =
clusters_average =

# %% [markdown]
# ## **4. Visualisasi Hasil Cluster**

# %% [markdown]
# ### **A. Single Linkage**

# %%
# Visualisasi Cluster Single Linkage
plt.figure(figsize=(10, 7))
plt.scatter(df['____'], df['____'], c=clusters_single, cmap='viridis', s=10)
plt.title('Cluster Visualization - Single Linkage')
plt.xlabel('____')
plt.ylabel('____')
plt.colorbar(label='Cluster')
plt.show()

# %% [markdown]
# ### **B. Complete Linkage**

# %%
# Visualisasi cluster Complete Linkage
plt.figure(figsize=(10, 7))
plt.scatter(df['____'], df['____'], c=clusters_complete, cmap='viridis', s=10)
plt.title('Cluster Visualization - Complete Linkage PCA')
plt.xlabel('____')
plt.ylabel('____')
plt.colorbar(label='Cluster')
plt.show()

# %% [markdown]
# ### **C. Average Linkage**

# %%
# Visualize cluster Average Linkage
plt.figure(figsize=(10, 7))
plt.scatter(df['____'], df['____'], c=clusters_average, cmap='viridis', s=10)
plt.title('Cluster Visualization - Average Linkage PCA')
plt.xlabel('____')
plt.ylabel('____')
plt.colorbar(label='Cluster')
plt.show()

# %% [markdown]
# ## **5. Evaluasi Clustering**

# %% [markdown]
# Lakukan Evaluasi dengan metode silhouette_score, calinski_harabasz_score, davies_bouldin_score, adjusted_rand_score, dan cek purity score dengan fitur bebas

# %%
def calculate_clustering_metrics(clusters, df):
    silhouette = ____
    calinski_harabasz = ____
    davies_bouldin = ____
    return silhouette, calinski_harabasz, davies_bouldin
metrics_single = calculate_clustering_metrics(clusters_single, ___)
metrics_complete = calculate_clustering_metrics(clusters_complete, ___)
metrics_average = calculate_clustering_metrics(clusters_average, ___)
print("Single Linkage Metrics:", metrics_single)
print("Complete Linkage Metrics:", metrics_complete)
print("Average Linkage Metrics:", metrics_average)


def purity_score(y_true, y_pred):
    # Compute contingency matrix
    ____ = np.zeros((____, ____))
    for ____ in range(____):
        ____[____][____] += ____
    return np.sum(np.amax(____, axis=____)) / np.sum(____)

# Calculate purity score
Y = ___['____'].values
labels = clusters_.....
# Calculate purity score
purity = purity_score (Y, labels)
print (f"Purity: {purity}")

# %% [markdown]
# ## **6. Analisis dan Pertanyaan**

# %% [markdown]
# 1. Dalam tugas ini, kamu diminta menggunakan PCA. Jelaskan yang dimaksud dengan PCA dan kegunaannya pada kasus ini?
# 2. Jelaskan arti dari setiap metrik evaluasi yang digunakan (Silhouette Score, Calinski-Harabasz Index, Davies-Bouldin Index, dan Purity Score) dan menurut analisis kamu, kapan metrik evaluasi ini menunjukan bahwa hasilnya "bagus".
# 3. Berdasarkan hasil evaluasi yang kamu lakukan, metode linkage mana yang menghasilkan cluster terbaik? Jelaskan alasannya.
# 4. Dari hasil pengujian kamu, apa kelemahan dan keterbatasan dari metode hierarchical clustering dan bandingkan dengan K-Means? BONUS jika kamu membandingkan langsung antara hasil K-Means dan Hierarchical clustering.

# %% [markdown]
# **Jawaban**
#
# 1.
