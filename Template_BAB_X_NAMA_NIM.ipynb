# %% [markdown]
# <a href="https://colab.research.google.com/github/helloohowareyu/Praktikum-Kecerdasan-Artifisial-Lanjut/blob/main/Template_BAB_X_NAMA_NIM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # LAPORAN PRAKTIKUM KECERDASAN ARTIFISIAL LANJUT
# **Nama: [Nama]**
#
# **NIM: [NIM]**
#
# **Kelas: KAL - [KELAS]**
#
# ---
# ## Bab 8 : Algoritma Prediksi menggunakan Regresi

# %% [markdown]
# ## Implementasi Regresi Linear dan Regresi Polinomial

# %% [markdown]
# ### 1) Dataset Sintetis

# %% [markdown]
# ### 2) Regresi Linear

# %%
# Gradient Descent

# %% [markdown]
# ### 3) Regresi Polinomial

# %%
# Buat fitur polinomial

# %%
# Gradient Descent

# %% [markdown]
# ## TUGAS

# %% [markdown]
# ### Soal 1
# **Tugas A: Regresi Linear**

# %% [markdown]
# Pertama, saya menggunakan 200 data acak dengan data generasi sebagai berikut
#
# $ y = 7 + 2.5 x + \varepsilon, dengan  \varepsilon \in N (0,1) $

# %% [markdown]
# Setelah itu, cetak nilai akhir dari parameter w0 dan w1

# %% [markdown]
# ### 1) Hitung dan tampilkan: a. Nilai Mean Squared Error (MSE) b. Plot garis regresi di atas data

# %% [markdown]
# Htung dan cetak MSE (Mean Squared Error) dan tampilkan plot regresi dengan line hasil prediksi

# %% [markdown]
# ### 2) Ubah nilai learning rate (a) menjadi 0.001 dan 1.0. Amati dan jelaskan perbedaan konvergensinya

# %% [markdown]
# Percobaan Learning rate dari menjadi 0.001 dan 1.0

# %% [markdown]
# Dikarenakan 1.0 tidak menghasilkan bobot apapun, hal ini perlu diidentifikasi. Tetapi tidak bisa divisualisasikan karna bobot error.

# %% [markdown]
# Berikut ini adalah evaluasi model dan visualisasi hasil MSE dan plot data

# %% [markdown]
# #### Penjelasan

# %% [markdown]
# ### Soal 2
#
# **Regresi Polinomial**

# %% [markdown]
# ### 1) Buat regresi polinomial derajat 2 dari awal. Implementasikan gradient descent dan tampilkan parameter Wo, W1,W2

# %% [markdown]
# Pertama, saya menggunakan 150 data acak rentang -2 hingga 2

# %% [markdown]
# Cetak parameter masing-masing bobot (w0, w1 dan w2) hasil model regresi polinomial

# %% [markdown]
# ### 2) Bandingkan MSE antara: a) Regresi linier (fit hanya wo + W₁x) b) Regresi polinomial (fit hingga w₂ x²)

# %% [markdown]
# Hasil analisis MSE dari regresi linear dan regresi polinomial

# %% [markdown]
# Regresi Linear

# %% [markdown]
# Regresi Polinomial

# %% [markdown]
# #### Penjelasan

# %% [markdown]
# ### 3) Visualisasikan kedua model regresi pada grafik yang sama dan diskusikan model mana yang lebih baik? Apa indikatornya?

# %% [markdown]
# Visualisasikan model regresi dengan grafik yang sama

# %% [markdown]
# #### Penjelasan

# %% [markdown]
# ### Soal 3
#
# **Eksplorasi dan Analisis**

# %% [markdown]
# ### 1) Tambahkan derajat polinomial menjadi 5 (quintik). Apakah model menjadi lebih baik atau justru overfitting?

# %% [markdown]
# Jika derajat polinomial menjadi 5 (lebih baik atau lebih buruk?)

# %% [markdown]
# ### 2) Buat fungsi predict(x, w) yang menerima data baru dan bobot hasil training, lalu mengembalikan hasil prediksi.

# %% [markdown]
# Fungsi predict (x, w) yang menerima data baru dan bobot hasil training lalu mengembalikan hasil prediksi

# %% [markdown]
# Berikut adalah contoh bagaimana prediksi jika menggunakan data sampel berupa -1.5, 0.5 dan 1.5 dan berikut merupakan hasil prediksi model

# %% [markdown]
# #### Penjelasan

# %% [markdown]
# ### 3) Tulis kesimpulan Anda:
#
# 1. Kapan kita perlu menggunakan regresi linier?
#
# **Jawaban:**
#
#
# 2. Kapan regresi polinomial lebih cocok?
#
# **Jawaban:**
#
#
# 3. Apa dampak jumlah epoch dan learning rate terhadap performa training?
#
# **Jawaban:**

# %% [markdown]
# ### Kesimpulan
